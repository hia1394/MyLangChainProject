# %% [markdown]
# ## 0. 환경 구성

# %% [markdown]
# ### 1) 라이브러리 설치

# %%
# poetry add langchain_community faiss-cpu

# %% [markdown]
# ### 2) OpenAI 인증키 설정
# https://openai.com/

# %%
from dotenv import load_dotenv
import os

# .env 파일을 불러와서 환경 변수로 설정
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(OPENAI_API_KEY[:5])
# Out:
# gsk_z

# %%
EMBEDDING_MODEL_NAME = "bge-m3:latest"

# %% [markdown]
# #### RAG 파이프 라인
# * Load Data - Text Split - Indexing - Retrieval - Generation
# * OllamaEmbeddings 사용

# %%
from langchain_openai import ChatOpenAI,OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import TextLoader
from langchain_ollama import OllamaEmbeddings

from pprint import pprint

# 1. Load Data
loader = TextLoader("../data/taxinfo.txt", encoding="utf-8")
documents = loader.load()
print(type(documents), len(documents)) #[Documentm, Document]
print(type(documents[0]))
#print(documents[0])
# Out:
# context 적용한 결과
# ('소득세법 제12조(비과세소득)에 따라 소득세를 부과하지 않는 「비과세소득」의 주요 내용은 다음과 같습니다. (2023. 12. 31. '
#  '현행 조문 기준)\n'
#  '\n'
#  '1. **공익신탁 이익**  \n'
#  '   - 「공익신탁법」에 따른 공익신탁으로부터 발생한 이익\n'
#  '\n'
#  '2. **사업소득 중 비과세 대상**  \n'
#  '   - 농지(논·밭)를 작물 생산에 이용해 발생한 소득  \n'
#  '   - 1주택 임대소득(기준시가 12억 원 이하, 국내 주택에 한함) 또는 연 2천만 원 이하 임대소득(2018 과세기간까지 '
#  '한정)  \n'
#  '   - 대통령령이 정하는 농어가(農漁家) 부업소득  \n'
#  '   - 전통주 제조소득(대통령령 기준)  \n'
#  '   - 조림 5년 이상 임지의 임목 벌채·양도소득(연 600만 원 이하 한도)  \n'
#  '   - 대통령령이 정하는 작물재배업·어로·양식어업 소득\n'
#  '\n'
#  '3. **근로·퇴직소득 중 비과세**  \n'
#  '   - 복무 중 병사 급여  \n'
#  '   - 법령에 따른 동원근로 급여  \n'
#  '   - 산재보상보험 요양·휴업·장해·간병·유족급여 등  \n'
#  '   - 근로기준법·선원법상 보상금(요양·휴업·장해·유족보상금 등)  \n'
#  '   - 종교인소득 중 대통령령·기획재정부령으로 정하는 학자금·식사대·실비변상 지급액, 출산·보육지원비(월 20만 원 한도), 사택 제공 '
#  '이익  \n'
#  '   - 보수를 받지 않는 위원회 위원 등이 받는 수당  \n'
#  '   - 「산업재해보상보험법」 각종 연금  \n'
#  '   - 「국군포로송환법」 연금\n'
#  '\n'
#  '4. **기타소득 중 비과세**  \n'
#  '   - 국가유공자·보훈대상자 보훈급여, 학습보조비, 북한이탈주민 정착금·보로금  \n'
#  '   - 「국가보안법」 상금·보로금  \n'
#  '   - 「상훈법」 훈장 부상(副賞), 대통령령이 정하는 상금·부상  \n'
#  '   - 퇴직 후 직무발명보상금(대통령령 기준 한도, 특수관계인 제외)  \n'
#  '   - 국군포로 위로지원금  \n'
#  '   - 국가지정문화유산(서화·골동품) 양도소득  \n'
#  '   - 박물관·미술관에 서화·골동품 양도소득  \n'
#  '   - 종교인소득 중 대통령령이 정하는 범위의 금품·급여\n'
#  '\n'
#  '요약하면, 농어업·임업·전통주 제조 등 일정 소규모 사업소득, 1주택 임대소득, 국가보훈·산재보상·종교인 지원금 등 법률이 정하는 일정 '
#  '금액·요건을 충족하는 소득은 소득세가 부과되지 않습니다.')
# context 적용하지 않은 결과
# ('소득세법에서 **비과세소득**은 소득세를 부과하지 않는 소득으로, 법률에 명시된 특정 소득에 한해 인정됩니다. 주요 비과세소득은 다음과 '
#  '같습니다:\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### ✅ **소득세법 조문 기준 주요 비과세소득** (소득세법 제12조 및 별표1)\n'
#  '\n'
#  '| 소득 유형 | 비과세 요건 |\n'
#  '|------------|--------------|\n'
#  '| **국민기초생활보장법에 따른 생계급여** | 법에 따라 지급받는 급여 |\n'
#  '| **장애인연금** | 장애인연금법에 따라 지급받는 연금 |\n'
#  '| **국가유공자 보상금·연금** | 국가유공자 등 예우 및 지원에 관한 법률에 따른 금품 |\n'
#  '| **재해복구금·재해보상금** | 자연재해 등으로 인한 피해 복구 목적의 금품 |\n'
#  '| **근로자의 퇴직금·퇴직연금** | 일정 한도 내에서 비과세 (예: 연간 3천만원 한도) |\n'
#  '| **출산휴업급여** | 고용보험법에 따른 출산휴업급여 |\n'
#  '| **육아휴직급여** | 고용보험법에 따른 육아휴직급여 |\n'
#  '| **국민연금, 공무원연금, 군인연금, 사학연금** | 연금소득으로서 일정 요건 충족 시 |\n'
#  '| **장학금·학자금** | 대학생 이하의 학생이 받는 장학금 (일정 한도 내) |\n'
#  '| **이자소득 중 비과세 이자** | 예금 이자 2천만원 한도, 주택청약종합저축 이자 등 |\n'
#  '| **증여·상속재산** | 증여세법·상속세법에 따라 과세되는 재산은 소득세 과세 대상 아님 |\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### ⚠️ 주의할 점\n'
#  '- **비과세 ≠ 면제세액**: 비과세는 소득 자체를 과세하지 않는 것이지, 세액을 공제해주는 것이 아닙니다.\n'
#  '- **일정 한도 초과 시 과세**: 예를 들어 퇴직금은 연간 3천만원 초과분에 대해 과세됩니다.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '필요하시면 **특정 소득이 비과세인지 여부**를 구체적으로 알려주시면 판단해드릴 수 있습니다.')

# %%
  
# 2️. Text Split
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
split_docs = splitter.split_documents(documents)
#print(split_docs)
# Out:
# context 적용한 결과
# ('소득세법 제12조(비과세소득)에 따라 소득세를 부과하지 않는 「비과세소득」은 크게 다음과 같이 분류됩니다. 아래는 2023. 12. '
#  '31. 현행 조문을 바탕으로 한 정리입니다.\n'
#  '\n'
#  '1. 공익신탁 이익  \n'
#  '   - 「공익신탁법」에 따른 공익신탁으로부터 발생하는 이익\n'
#  '\n'
#  '2. 사업소득 중 비과세 대상  \n'
#  '   - 농지(논·밭)를 작물 생산에 이용해 발생한 소득  \n'
#  '   - 1주택자의 주택임대소득(기준시가 12억 원 이하, 국내 주택만)  \n'
#  '   - 총수입 2천만 원 이하 주택임대소득(2018 과세기간까지 한정)  \n'
#  '   - 농어가부업소득(대통령령 정한 범위)  \n'
#  '   - 전통주 제조소득(대통령령 정한 범위)  \n'
#  '   - 조림 5년 이상 임지의 임목 벌채·양도소득(연 600만 원 이하)  \n'
#  '   - 대통령령이 정하는 작물재배업·어로·양식어업 소득\n'
#  '\n'
#  '3. 근로·퇴직소득 중 비과세 대상  \n'
#  '   - 복무 중 병사 급여  \n'
#  '   - 법령에 따른 동원근로자 급여  \n'
#  '   - 산재보험 요양·휴업·장해·간병·유족급여 등  \n'
#  '   - 근로기준법·선원법상 보상금(요양·휴업·상병·장해·유족보상금 등)  \n'
#  '   - 종교인소득 중 학자금·식사대·실비변상적 급여·출산·보육지원비(월 20만 원 한도)·사택 제공 이익  \n'
#  '   - 법령·조례에 따라 보수를 받지 않는 위원 등이 받는 수당  \n'
#  '   - 산재보험 연금, 국군포로 연금\n'
#  '\n'
#  '4. 기타소득 중 비과세 대상  \n'
#  '   - 국가유공자 보훈급여·학습보조비, 북한이탈주민 정착금·보로금  \n'
#  '   - 국가보안법상 상금·보로금  \n'
#  '   - 상훈법에 따른 훈장 부상·상금  \n'
#  '   - 퇴직 후 직무발명보상금(대통령령이 정하는 한도, 특수관계인 제외)  \n'
#  '   - 국군포로 위로지원금  \n'
#  '   - 국가지정문화유산(서화·골동품) 양도소득  \n'
#  '   - 박물관·미술관에 서화·골동품 양도소득  \n'
#  '   - 종교인소득 중 대통령령으로 정하는 범위의 금품\n'
#  '\n'
#  '요약하면, 농업·임업·어업·1주택 임대·종교인 실비성 급여·산재·보훈·문화재 양도 등 법률이 정하는 일정한 조건을 충족하는 소득은 '
#  '소득세가 없습니다.')
# context 적용하지 않은 결과
# ('소득세법에서 **비과세소득**은 말 그대로 **소득세를 부과하지 않는 소득**을 말합니다.  \n'
#  '이는 소득세법 제12조 및 별표1에 규정되어 있으며, 대표적인 비과세소득은 다음과 같습니다:\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### ✅ 주요 비과세소득 (소득세법 제12조 및 별표1)\n'
#  '\n'
#  '| 항목 | 내용 |\n'
#  '|------|------|\n'
#  '| **1. 이자·배당 소득** | - 국민주택채권 이자<br>- 장기주택저당공사채 이자<br>- 우체국 예금 이자(일정 한도 내) |\n'
#  '| **2. 근로소득** | - 외국인 기술자의 기술서비스료(일정 조건 충족 시)<br>- 국가유공자 등의 보훈급여 |\n'
#  '| **3. 연금소득** | - 국민연금, 공무원연금, 군인연금 등 공적연금(일정 한도 내) |\n'
#  '| **4. 기타 소득** | - 정부·지자체의 보조금·장려금(일정 조건)<br>- 재난지원금, 코로나19 관련 지원금<br>- 학자금 '
#  '지원(일정 한도 내) |\n'
#  '| **5. 퇴직소득** | - 5년 이상 근속 후 퇴직 시 퇴직금의 일정 부분(비과세 한도 적용) |\n'
#  '| **6. 농어업인 소득** | - 농어업인의 농산물 판매 소득(일정 한도 내) |\n'
#  '| **7. 증여·상속** | - 증여세법·상속세법에서 비과세되는 증여·상속 재산 |\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### ⚠️ 주의할 점\n'
#  '- **비과세 ≠ 비신고**: 비과세 소득도 **종합소득세 신고 대상**일 수 있으며, 일부는 **간이신고** 또는 **원천징수** '
#  '대상일 수 있습니다.\n'
#  '- **한도 초과 시 과세**: 일부 비과세 소득은 **일정 한도 내에서만** 비과세 적용됩니다 (예: 이자소득, 농산물 판매 소득 '
#  '등).\n'
#  '\n'
#  '---\n'
#  '\n'
#  '필요하시면 **특정 소득 항목**이 비과세인지 확인해드릴 수 있습니다.')

# %%
# 3️. Indexing (벡터 저장)
embeddings_model = OllamaEmbeddings(model=EMBEDDING_MODEL_NAME)
vectorstore = FAISS.from_documents(
    documents=split_docs, 
    embedding=embeddings_model
)
#vectorstore = FAISS.from_documents(split_docs, OpenAIEmbeddings())

# 로컬 파일로 저장
vectorstore.save_local("faiss_index")

# %%
# 4️. Retrieval (유사 문서 검색) k: 질의와 가장 유사한 문서(청크) 6개를 찾아 반환하기
retriever = vectorstore.as_retriever(search_kwargs={"k": 6})
# **질문(쿼리)**에 대해 유사한 문서를 검색하는 역할
retrieved_docs = retriever.invoke("소득세법에서 비과세소득에 해당하는 소득은 무엇인가요?")
#print(retrieved_docs)

# %%
# 5️. Generation (LLM 응답 생성)
#llm = ChatOpenAI(model="gpt-4o-mini")
llm = ChatOpenAI(
    base_url="https://api.groq.com/openai/v1",
    #model="meta-llama/llama-4-scout-17b-16e-instruct",
    model="moonshotai/kimi-k2-instruct-0905",
    temperature=0
)
context = "\n\n".join([doc.page_content for doc in retrieved_docs])
#print(context)

response_context = llm.invoke(f"소득세법에서 비과세소득에 해당하는 소득은 무엇인가요? 관련 정보: {context}")
print('context 적용한 결과')
pprint(response_context.content)

response = llm.invoke(f"소득세법에서 비과세소득에 해당하는 소득은 무엇인가요?")
print('context 적용하지 않은 결과')
pprint(response.content)

# %% [markdown]
# ### 개선한 Source - version1
# * Retriever 검색방법 개선
#     * search_type="mmr",  # 최대 다양성 검색
#     * search_kwargs={"k": 6, "fetch_k": 10}

# %%
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import TextLoader
from langchain_ollama import OllamaEmbeddings

from pprint import pprint

# 1. 데이터 로드 (기존과 동일)
loader = TextLoader("../data/taxinfo.txt", encoding="utf-8")
documents = loader.load()

# 2. 텍스트 분할 개선
splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,  # 크기 증가
    chunk_overlap=200,
    separators=["\n\n", "\n", " ", ""],  # 자연스러운 분할을 위한 구분자
    length_function=len,
    is_separator_regex=False,
)
split_docs = splitter.split_documents(documents)

# 3. 인덱싱 (벡터 저장)
embeddings_model = OllamaEmbeddings(model=EMBEDDING_MODEL_NAME)

vectorstore = FAISS.from_documents(
    documents=split_docs, 
    embedding=embeddings_model
)
#vectorstore = FAISS.from_documents(split_docs, OpenAIEmbeddings())

vectorstore.save_local("faiss_index")

# 4. 검색 개선
"""
    최대 다양성 검색(Maximum Marginal Relevance, MMR)
    MMR은 유사도가 높은 문서를 찾는 것을 넘어, 유사도와 다양성이라는 두 가지 기준을 모두 고려험
    - search_type="mmr": 검색 방식을 MMR로 지정합니다.
    - fetch_k: 일차적으로 질의와 유사한 문서 10개를 벡터 저장소에서 가져옵니다.
    - k: fetch_k로 가져온 10개의 문서 중에서 최종적으로 6개를 선택합니다. 6개를 선택할 때, MMR 알고리즘은 다음 두 가지를 고려함
        : 질의와의 유사도가 높고, 이미 선택된 다른 문서들과의 유사도가 낮은 (즉, 내용이 다양한) 문서
    * MMR의 작동 원리:
    - 질의와 가장 유사한 fetch_k개(10개)의 문서를 예비 후보군으로 가져옵니다.
    - 이 후보군 중에서 질의와 가장 유사한 문서 하나를 첫 번째 결과로 선택합니다.
    - 남은 후보군 중에서 질의와의 유사도는 높으면서 (관련성), 
      이미 선택된 문서들과의 유사도는 낮은 (다양성) 문서를 찾아 다음 결과로 추가함
    - 이 과정을 k개(6개)의 문서가 모두 선택될 때까지 반복합니다.        
"""
retriever = vectorstore.as_retriever(
    search_type="mmr",  # 최대 다양성 검색
    search_kwargs={"k": 6, "fetch_k": 10}  # 더 많은 결과 검색
)

# 5. 프롬프트 엔지니어링
def generate_prompt(query, context):
    return f"""다음은 소득세법 비과세소득 관련 조항입니다. 문맥을 고려하여 질문에 답변하세요.

[관련 조항]
{context}

[질문]
{query}

[답변 요구사항]
- 비과세소득 유형을 계층적으로 구분하여 설명
- 각 항목별 구체적인 조건 명시
- 법조문의 항, 호, 목 번호를 포함
- 500자 이내로 간결하게 요약"""

# 검색 및 응답 생성
query = "소득세법에서 비과세소득에 해당하는 소득은 무엇인가요?"
retrieved_docs = retriever.invoke(query)
context = "\n\n".join([doc.page_content for doc in retrieved_docs])

#llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.3)  # 창의성 낮춤
llm = ChatOpenAI(
    base_url="https://api.groq.com/openai/v1",
    #model="meta-llama/llama-4-scout-17b-16e-instruct",
    model="moonshotai/kimi-k2-instruct-0905",
    temperature=0
)
response = llm.invoke(generate_prompt(query, context))

print('개선된 결과:')
pprint(response.content)

# %% [markdown]
# ### 개선한 Source - version2
# * Prompt 개선

# %%
from langchain_openai import ChatOpenAI,OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import TextLoader
from langchain_ollama import OllamaEmbeddings

from pprint import pprint

# 1. Load Data
loader = TextLoader("../data/taxinfo.txt", encoding="utf-8")
documents = loader.load()

print("=== 원본 문서 길이 ===")
print(f"전체 문서 길이: {len(documents[0].page_content)} 글자")

# 2. Text Split 개선
splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,  
    chunk_overlap=150,
    separators=["\n\n", "\n", ". ", " ", ""]  # 법령 구조에 맞는 분리자
)
split_docs = splitter.split_documents(documents)

print(f"분할된 문서 수: {len(split_docs)}개")
print("=== 분할 예시 ===")
for i, doc in enumerate(split_docs[:3]):
    print(f"Chunk {i+1} ({len(doc.page_content)}글자): {doc.page_content[:100]}...")

# 3. Indexing
embeddings_model = OllamaEmbeddings(model=EMBEDDING_MODEL_NAME)

vectorstore = FAISS.from_documents(
    documents=split_docs, 
    embedding=embeddings_model
)

#vectorstore = FAISS.from_documents(split_docs, OpenAIEmbeddings())
vectorstore.save_local("faiss_index")

# 4. Retrieval 개선
retriever = vectorstore.as_retriever(
    search_type="similarity", 
    search_kwargs={"k": 6}  
)

query = "소득세법에서 비과세소득에 해당하는 소득은 무엇인가요?"
retrieved_docs = retriever.invoke(query)

print(f"\n=== 검색된 문서 ({len(retrieved_docs)}개) ===")
for i, doc in enumerate(retrieved_docs):
    print(f"문서 {i+1}: {doc.page_content[:200]}...")
    print("---")

# 5. Generation - 개선된 프롬프트
#llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
llm = ChatOpenAI(
    base_url="https://api.groq.com/openai/v1",
    #model="meta-llama/llama-4-scout-17b-16e-instruct",
    model="moonshotai/kimi-k2-instruct-0905",
    temperature=0
)
context = "\n\n".join([f"[문서 {i+1}]\n{doc.page_content}" for i, doc in enumerate(retrieved_docs)])

# 개선된 프롬프트 - 더 구체적인 지시사항
improved_prompt = f"""
당신은 세무 전문가입니다. 아래 소득세법 제12조 조항을 바탕으로 질문에 답변해주세요.

질문: {query}

법령 조항:
{context}

다음 형식으로 답변해주세요:
1. 비과세소득의 정의
2. 주요 비과세소득 항목들을 다음과 같이 분류:
   - 사업소득 관련
   - 근로소득/퇴직소득 관련  
   - 연금소득 관련
   - 기타소득 관련
3. 각 항목별 구체적인 조건이나 한도액 명시

답변은 법조문을 인용하면서 구체적으로 작성해주세요.
"""

# 비교용 - 기존 방식
simple_prompt = f"소득세법에서 비과세소득에 해당하는 소득은 무엇인가요? 관련 정보: {context}"

print("\n=== 개선된 프롬프트로 답변 ===")
response_improved = llm.invoke(improved_prompt)
pprint(response_improved.content)

print("\n" + "="*50)
print("=== 기존 프롬프트로 답변 ===")
response_simple = llm.invoke(simple_prompt)
pprint(response_simple.content)

# 추가 개선: 다른 검색 방식 시도
print("\n" + "="*50)
print("=== 검색 방식 개선 테스트 ===")

# MMR(Maximum Marginal Relevance) 검색 - 다양성 확보
retriever_mmr = vectorstore.as_retriever(
    search_type="mmr",
    search_kwargs={"k": 6, "fetch_k": 20}
)
retrieved_docs_mmr = retriever_mmr.invoke(query)
context_mmr = "\n\n".join([f"[문서 {i+1}]\n{doc.page_content}" for i, doc in enumerate(retrieved_docs_mmr)])

response_mmr = llm.invoke(f"""
{query}

법령 조항 (MMR 검색):
{context_mmr}

위 법령을 바탕으로 비과세소득 항목들을 체계적으로 정리해주세요.
""")

print("=== MMR 검색 결과 ===")
pprint(response_mmr.content)
