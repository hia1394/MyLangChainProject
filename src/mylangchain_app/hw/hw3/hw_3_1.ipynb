# %%
from dotenv import load_dotenv
import os

# .env 파일을 불러와서 환경 변수로 설정
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(OPENAI_API_KEY[:5])
# Out:
# gsk_4

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_upstage import ChatUpstage
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain_upstage import UpstageEmbeddings


loader = PyPDFLoader('../../data/콘텐츠분쟁해결_사례.pdf')
documents = loader.load()
print(f"  총 {len(documents)}페이지 로드 완료")



pythontext_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,        #  법률 사례는 1200-1800자 권장
    chunk_overlap=300,      #  사례 맥락 보존을 위해 200-400자
    separators=[
        "\n【사건개요】",     #  법률 문서 섹션 구분자
        "\n【쟁점사항】",     #  쟁점 부분 구분
        "\n【처리경위】",     #  처리 과정 구분
        "\n【처리결과】",     #  결과 부분 구분
        "\n■", "\n\n", "\n", ".", " ", ""
    ]
)

chunks = pythontext_splitter.split_documents(documents)

print(f"  {len(chunks)}개 청크 생성 완료")
print(f"  평균 청크 길이: {sum(len(chunk.page_content) for chunk in chunks) / len(chunks):.0f}자")
print(type(chunks[0]))

pythonembeddings = UpstageEmbeddings(model="solar-embedding-1-large")


vectorstore = FAISS.from_documents(chunks, pythonembeddings)

print(f" FAISS 벡터스토어 생성 완료 ({len(chunks)}개 벡터)")

vectorstore.save_local("faiss_db")

pythonretriever = vectorstore.as_retriever(
    search_type="similarity",        
    search_kwargs={"k": 5}          
    
)

pythonllm = ChatUpstage(
        model="solar-pro",
        base_url="https://api.upstage.ai/v1",
        temperature=0.2
    )

pythonprompt_template = """
당신은 콘텐츠 분야 전문 법률 자문가입니다. 
아래 분쟁조정 사례들을 바탕으로 정확하고 전문적인 법률 조언을 제공해주세요.

관련 분쟁사례:
{context}

상담 내용: {question}

답변 가이드라인:
1. 제시된 사례들을 근거로 답변하세요                    # 사례 기반 답변
2. 관련 법령이나 조항이 있다면 명시하세요               # 법적 근거 제시
3. 비슷한 사례의 처리경위와 결과를 참고하여 설명하세요    # 판례 참조
4. 실무적 해결방안을 단계별로 제시하세요               #  실무 가이드
5. 사례에 없는 내용은 "제시된 사례집에서는 확인할 수 없습니다"라고 명시하세요  #  한계 인정

전문 법률 조언:"""

prompt_template = PromptTemplate(
    input_variables=["context", "question"],  # 템플릿 안에 사용된 변수명
    template=pythonprompt_template
)

pythonqa_chain = RetrievalQA.from_chain_type(
    llm=pythonllm,
    chain_type="stuff",
    retriever=pythonretriever,
    chain_type_kwargs={"prompt": prompt_template},  # ✅ 올바른 PromptTemplate 전달
    return_source_documents=True
)

pythontest_questions = [
    "온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?",
    "인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?",
    "무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?",
    "미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?",
    "온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?"
]

for i, question in enumerate(pythontest_questions, 1):
    print(f"\n【질문 {i}/5】")
    print(f" 질문: {question}")
    print(" 답변 생성 중...")
    
    # RAG 실행
    result = pythonqa_chain.invoke({"query": question})
    answer = result["result"]
    source_docs = result["source_documents"]
    
    print(f"\n 답변:")
    print("-" * 50)
    print(answer)
    
    # 참조 문서 정보
    print(f"\n 참조 문서:")
    for j, doc in enumerate(source_docs[:3], 1):
        page = doc.metadata.get('page', 'N/A')
        preview = doc.page_content[:80].replace('\n', ' ')
        print(f"   {j}. 페이지 {page}: {preview}...")
    
    print("\n" + "-" * 40)
# Out:
#   총 109페이지 로드 완료
#   104개 청크 생성 완료
#   평균 청크 길이: 753자
# <class 'langchain_core.documents.base.Document'>
#  FAISS 벡터스토어 생성 완료 (104개 벡터)
#
# 【테스트 1/5】
#  질문: 온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# ### 전문 법률 조언: 온라인 게임 시스템 오류로 인한 아이템 복구 거부 사례
#
# #### 1. **사례 기반 분석**
# 제시된 사례집을 종합하면, 시스템 오류로 인한 아이템 복구 문제는 다음과 같은 요소에 따라 결과가 달라집니다:
# - **계정 소유권 확인**: 계정 명의자와 실소유자가 다를 경우 복구가 거절될 수 있음(2006년 사례).
# - **오류 입증 가능성**: 시스템 오류가 객관적으로 확인되지 않거나, 다른 사용자에게 동일한 문제가 발생하지 않은 경우 복구 요구가 어려움(2009년 사례).
# - **회사의 복구 정책**: 프로그램 오류를 인정한 경우 복구가 가능했으나(2006년 사례), 약관상 책임 한계가 명시된 경우 거부될 수 있음(2007년 사례).
#
# #### 2. **법적 근거**
# - **민법 제250조(도품·유실물 특례)**:
#   - 아이템이 해킹 또는 시스템 오류로 소멸된 경우, 게임사는 "유실물 반환의무"를 질 수 있으나, **금전적 가치가 없는 디지털 아이템**은 적용 대상이 아닐 수 있음.
#   - 단, 아이템에 실제 금전적 투자(예: 현금 결제)가 있었다면 "재산적 가치"로 인정될 여지가 있음.
# - **전자상거래법 제17조(디지털콘텐츠 공급자의 의무)**:
#   - 시스템 오류로 인해 이용자가 피해를 입은 경우, 사업자는 **합리적인 조치**(복구, 보상 등)를 취해야 함.
# - **약관의 규제에 관한 법률 제6조(불공정 약관 무효)**:
#   - "모든 시스템 오류에 대한 책임을 지지 않는다"는 조항은 불공정 약관으로 무효될 수 있음.
#
# #### 3. **실무적 해결 방안**
# **(1) 증거 수집 및 보존**
# - **시스템 오류 기록**: 게임 내 로그, 스크린샷, 고객센터 문의 내역 등을 보관.
# - **계정 소유권 증명**: 실명 인증, 결제 내역, IP 접속 기록 등으로 실소유자임을 입증.
#
# **(2) 게임사에 대한 공식 요청**
# - **고객센터 문의**: 오류 발생 일시, 아이템 가치, 복구 요청 사유를 명시한 공식 문서(이메일 등)로 요청.
# - **약관 확인**: "시스템 오류 시 복구 정책"이 있는지 확인. 예시:
#   > "회사는 기술적 오류로 인한 아이템 손실에 대해 30일 이내에 복구 요청을 접수할 수 있음."
#
# **(3) 분쟁 조정 신청**
# - **한국소비자원 또는 콘텐츠분쟁조정위원회**에 조정 신청:
#   - 2006년 사례와 같이 회사가 오류를 인정한 경우, 조정 성공 가능성 높음.
#   - 2009년 사례와 같이 오류가 입증되지 않으면 조정 거부될 수 있음.
#
# **(4) 소송 고려**
# - **민사소송(손해배상 청구)**:
#   - 아이템 구매 금액, 게임 이용료 등을 기준으로 손해액 산정.
#   - 단, **디지털 아이템의 재산적 가치**를 입증해야 하며, 판례상 인정 기준이 엄격함(대법원 2012다220171 참조).
#
# #### 4. **주의사항**
# - **계정 공유 또는 불법 프로그램 사용 이력**: 2009년 사례에서와 같이 계정 이용 제한 사유가 발견되면 복구 요구가 어려움.
# - **게임머니의 현실 금전성**: 1,000억 게임머니와 같이 과도한 금액은 실제 피해로 인정되기 힘듦(2009년 사례 참조).
#
# #### 5. **한계점**
# - 제시된 사례집에는 **"디지털 아이템의 재산적 가치"**를 명시적으로 인정한 판례가 없으며, 대부분의 사례에서 게임사의 약관 또는 기술적 한계가 우선시됨.
# - **해킹 피해**의 경우(2009년 사례), 게임사의 보안 의무 위반이 입증되어야 보상이 가능함.
#
# ### 결론
# 시스템 오류로 인한 아이템 복구 문제는 **증거 확보**와 **게임사의 복구 정책**이 핵심입니다. 한국소비자원에 조정을 신청하거나, 약관이 불공정한 경우 무효를 주장하며 소송을 고려할 수 있으나, 성공 가능성은 개별 사정에 따라 다릅니다.
#
# > ✅ **추천 조치**:
# > 1. 게임사에 공식 문서(이메일)로 복구 요청.
# > 2. 한국소비자원(☎ 1372) 또는 [콘텐츠분쟁조정위원회](https://www.kcdrc.kr)에 상담 신청.
# > 3. 계정 소유권 및 오류 증거를 첨부하여 법적 조치 준비.
#
#  참조 문서:
#    1. 페이지 8: 1. 게임 3게임1 ■ 1-가-1) 한국소비자원 조정전 상담사례 2006_시스템 오류로 소멸된 아이템 복구 요구 【사건개요 】 신청인은 피신청인...
#    2. 페이지 28: 1. 게임 23■ 1-가-1) 한국소비자원 조정전 상담사례 2009_시스템 오류로 인한 손실 아이템 복구 요구 【사건개요 】 신청인은 2009....
#    3. 페이지 2: 2009_ 인터넷 게임 계정 영구이용 제한조치 취소 요구···································· 1 9 2009_ 사용...
#
# ----------------------------------------
#
# 【테스트 2/5】
#  질문: 인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# ### 전문 법률 조언: 인터넷 강의 중도 해지 시 과도한 위약금 요구의 적법성 검토
#
# #### 1. **사례 기반 분석**
# 제시된 한국소비자원 조정사례(2007~2010년)에 따르면, **온라인 교육서비스 중도 해지 시 과도한 위약금 공제는 대부분 부당**으로 판단되었습니다. 주요 쟁점은 다음과 같습니다:
# - **위약금 한도 초과 여부**: 방문판매 등에 관한 법률(이하 "방판법") 제30조는 "해지로 인한 손실을 현저히 초과하는 위약금 청구"를 금지하며, 소비자분쟁해결기준(공정위 고시)에 따라 **이용일수 + 총 이용대금의 10%**만 공제 가능합니다.
#   - 예시: 2007_인터넷교육서비스 중도해지 사례(57■)에서 피청구인은 1,632,000원을 공제했으나, 조정결과 **이용일수 + 10% 범위 내 환급**이 권고되었습니다.
# - **계약서 미기재 비용 공제 불가**: 사은품 비용, 가입비 등 계약서에 명시되지 않은 항목은 공제 대상이 아닙니다(2008_온라인통신교육서비스 사례 참조).
# - **실제 이용기간 기준**: 서비스 미제공 기간(예: 2010_화상강의 사례)은 공제 대상에서 제외됩니다.
#
# #### 2. **관련 법령**
# - **방판법 제30조(계약 해지 효과)**:
#   > "계속거래 계약 해지 시, 사업자는 소비자에게 **실제 이용 대가 + 합리적 위약금(10% 이내)**만 청구할 수 있으며, 초과 금액은 반환해야 함."
# - **소비자기본법 제16조 및 소비자분쟁해결기준**:
#   > "온라인 교육서비스 해지 시 **이용일수 + 총액의 10%**를 공제한 잔액 환급"을 원칙으로 합니다.
#
# #### 3. **실무적 해결방안 (단계별)**
# **(1) 계약서 확인**
# - 계약서에 명시된 **이용요금, 위약금 조항, 공제 항목**을 확인합니다.
# - **미기재 항목**(예: 사은품 비용)은 공제 요구 시 이의 제기 가능합니다.
#
# **(2) 이용기간 산정**
# - **실제 서비스 이용 가능일**부터 해지일까지 계산합니다(2010_화상강의 사례 참조).
#   - 예시: 계약일(2023.1.1) vs. 서비스 개통일(2023.1.15) → **1.15~해지일**만 공제 대상.
#
# **(3) 환급금 계산**
# - **공식**:
#   > `환급금 = 총 결제액 - (이용일수 × 월 이용료) - (총 결제액 × 10%)`
#   - 월 이용료는 **계약서 기재 금액**을 기준으로 하며, 할인액은 고려하지 않습니다(2008_온라인통신교육 사례).
#
# **(4) 사업자와의 협상**
# - 위 계산식을 근거로 **10% 초과 위약금 또는 미기재 비용 공제**를 거부합니다.
# - 사업자가 불응 시 **한국소비자원 분쟁조정위원회**에 조정을 신청합니다.
#
# **(5) 법적 조치**
# - 조정 실패 시 **소비자기본법 제16조**에 따라 **소비자분쟁조정위원회** 또는 **법원 소송**을 제기할 수 있습니다.
#
# #### 4. **주의사항**
# - **구두 해지 통보**는 증거력이 약하므로, **내용증명 우편**으로 해지 의사를 명시해야 합니다(2010_화상강의 사례).
# - **제시된 사례집에는 없는 내용**(예: 해외 서비스 계약, B2B 계약)은 본 답변의 적용 범위에서 제외됩니다.
#
# #### 5. **결론**
# 과도한 위약금 요구는 **방판법 및 소비자분쟁해결기준에 위반**될 가능성이 높습니다. 계약서 분석과 이용기간 산정을 통해 정당한 환급금을 요구하고, 사업자와의 협상이 어려울 경우 **공식 조정 절차**를 활용하시기 바랍니다.
#
# > ✅ **추천 조치**: 한국소비자원 홈페이지(www.kca.go.kr)에서 "소비자분쟁조정" 신청 → 무료 법률 지원 가능.
#
#  참조 문서:
#    1. 페이지 3: 2007_ 온라인통신교육서비스 대금 환급 요구2················································· 5 5 ...
#    2. 페이지 62: 2. 이러닝 57■ 2-가 한국소비자원 조정결정례 2007_인터넷교육서비스 중도해지 요구 【사건개요 】 청구인은 2006. 2. 8. 피청구인이...
#    3. 페이지 60: 2. 이러닝 55■ 2-가 한국소비자원 조정결정례 2007_온라인통신교육서비스 대금 환급 요구2 【사건개요 】 청구인은 2006. 10. 30....
#
# ----------------------------------------
#
# 【테스트 3/5】
#  질문: 무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# ### 전문 법률 조언: 무료체험 후 자동 유료전환 시 환불 가능성 검토
#
# #### 1. **사례 기반 분석**
# 제시된 사례(2010_무료 이벤트 후 자동 소액 결제 요금 환급요구, 2006_무료 광고 후 서비스 이용요금 청구)에 따르면, **무료체험 후 자동 유료전환으로 인한 요금 청구**는 다음과 같은 조건에서 환불 가능성이 있습니다:
# - **사업자의 고지의무 위반**:
#   - 무료체험 기간 종료 후 유료전환 사실을 **명확히 고지하지 않았거나**, 고지 내용이 소비자가 인지하기 어려운 경우(예: 작은 글씨, 복잡한 절차) 책임이 인정됩니다.
#   - 예시: 2010년 사례에서는 "이벤트 화면에 고지했으나 활자가 작아 확인이 어려웠다"는 이유로 사업자 책임이 50% 인정되었습니다.
# - **소비자의 인지 가능성**:
#   - 소비자가 유료전환을 인지할 수 있었음에도 **확인하지 않은 경우** 책임이 일부 발생할 수 있습니다(예: 4개월간 이의 없이 결제 시 50% 책임 제한).
#
# #### 2. **관련 법령**
# - **약관의 규제에 관한 법률 제3조(약관 작성 및 설명의무)**:
#   - 사업자는 계약 체결 시 **중요한 내용(유료전환 조건 등)**을 소비자가 이해할 수 있도록 명시·설명해야 합니다.
# - **소비자기본법 제18조(소비자분쟁해결기준)**:
#   - 불공정 약관 또는 고지의무 위반 시 계약 취소 또는 부분 환불이 가능합니다.
# - **표시·광고의 공정화에 관한 법률**:
#   - 무료체험을 광고하면서 유료전환 조건을 은폐한 경우 **부당표시**로 간주될 수 있습니다.
#
# #### 3. **유사 사례 처리 결과**
# - **2010년 사례**:
#   - 사업자 책임 50% 인정 → 4개월분 요금(30,800원)의 50%(15,400원) 환급.
#   - 근거: 고지 부족 + 소비자의 확인 소홀.
# - **2006년 사례**:
#   - 무료 광고 후 유료전환 사실을 명확히 고지하지 않아 **전액 환불** 권고.
#   - 근거: 소비자가 유료서비스로 오인할 수 있는 표시.
#
# #### 4. **실무적 해결방안 (단계별)**
# **(1) 증거 수집**
# - 무료체험 가입 시 **고지 내용**(화면 캡처, 약관 문서) 확인.
# - 유료전환 통보 **이메일/SMS** 등 기록 보관.
# - 결제 내역(금액, 기간) 정리.
#
# **(2) 사업자와의 협의**
# - **고지 부족**을 이유로 전액 또는 부분 환불 요청.
# - 예시: "무료체험 종료 후 유료전환 사실을 명확히 알리지 않았으므로, 관련 법령 위반으로 환불을 요구합니다."
#
# **(3) 분쟁조정 신청**
# - 협의 실패 시 **한국소비자원** 또는 **전자거래분쟁조정위원회**에 조정 신청.
# - 조정 시 **고지 방식**(글꼴 크기, 위치), **소비자의 인지 가능성**을 중점적으로 주장.
#
# **(4) 소송**
# - 조정 불발 시 **소비자기본법** 또는 **민법 제110조(사기·강박에 의한 의사표시)**를 근거로 소송 제기 가능.
#
# #### 5. **주의사항**
# - **제시된 사례집에서는 확인할 수 없는 내용**:
#   - 최근 5년 내 유사 판례 또는 **전자상거래법** 개정 사항(예: 2021년 개정법)은 본 사례집에 포함되지 않았습니다.
#   - 구체적인 환급 금액은 **이용 기간**, **고지 명확성**, **사업자의 과실 정도**에 따라 달라질 수 있습니다.
#
# #### 6. **결론**
# - **환불 가능성**은 사업자의 고지의무 이행 여부에 따라 결정됩니다.
# - 고지 내용이 불분명하거나 소비자가 인지하기 어려웠다면 **부분 또는 전액 환불**이 가능하며, 사례집과 법령을 근거로 적극적으로 권리를 주장해야 합니다.
#
# > ✅ **추천 조치**: 한국소비자원에 **무료 법률상담**을 신청하거나, **전자문서 증거보전**을 통해 향후 분쟁 시 대비하시기 바랍니다.
#
#  참조 문서:
#    1. 페이지 100: 3. 기타(웹) 95■ 3-가 한국소비자원 조정결정례 2010_무료 이벤트 후 자동 소액 결제 요금 환급요구 【사건개요 】 신청인은 2008. ...
#    2. 페이지 101: 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 96받는 것과는 달리 무료 이벤트 참여를 위한 회원 가입 시 인증번호를 부여받게 되어...
#    3. 페이지 102: 3. 기타(웹) 97■ 3-나 전자거래분쟁조정위원회 조정전합의 사례 2006_무료 광고 후 서비스 이용요금 청구 【사건개요 】 신청인은 한 사이...
#
# ----------------------------------------
#
# 【테스트 4/5】
#  질문: 미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# ### 전문 법률 조언: 미성년자 게임 아이템 구매 환불 가능성 검토
#
# #### 1. **사례 기반 분석**
# 제시된 분쟁조정 사례(2008_부당결제대금 반환 청구, 2006_미성년자 결제 취소 청구, 2008_미성년자 신용카드 부정사용 사례)에 따르면, **미성년자가 부모 동의 없이 타인의 명의를 도용하거나 성인 계정을 이용해 게임 아이템을 구매한 경우**, 환불 가능성은 다음과 같은 요소에 따라 결정됩니다:
# - **계약 당사자 확인**: 실제 계약자가 미성년자인지, 성인 명의를 도용했는지 여부.
# - **사술(詐術) 여부**: 미성년자가 성인인 것처럼 속이기 위해 타인의 개인정보를 고의로 사용했는지.
# - **사업자의 실명 확인 의무**: 게임사가 실명 인증 절차를 이행했는지, 또는 비실명 계정을 방치했는지.
#
# #### 2. **관련 법령**
# - **민법 제5조(미성년자의 능력)**: 미성년자가 법정대리인의 동의 없이 체결한 계약은 취소할 수 있음.
# - **민법 제17조(무능력자의 사술)**: 미성년자가 사술(속임수)로 성인인 것처럼 행동한 경우, 계약을 취소할 수 없음.
# - **전자상거래 등에서의 소비자보호에 관한 법률 제17조(청약철회)**: 미성년자의 경우 법정대리인이 청약철회를 할 수 있음.
#
# #### 3. **유사 사례 처리 결과**
# - **2006년 사례**: 미성년자가 성인 아이디로 결제한 경우, 사업자가 환불 거부했으나, **미성년자 본인 명의 결제분만 취소** 권고.
# - **2008년 사례(주민번호 도용)**: 미성년자가 타인 명의를 도용한 경우, **부모(감독자)와 사업자의 공동 책임**을 인정해 **부분 환불(65:35)** 결정.
# - **2008년 신용카드 부정사용 사례**: 미성년자가 성인인 것처럼 속인 경우, **사술로 간주해 환불 거부** 가능성 있으나, 사업자의 보안 조치 미비 시 부분 책임 인정.
#
# #### 4. **실무적 해결 방안**
# **(1) 1단계: 계약 취소 요건 검토**
# - 미성년자가 **부모 동의 없이** 결제했는지 확인 (예: 게임 이용 내역, 결제 수단).
# - **타인 명의 도용 여부** 확인 (예: 성인 계정 사용, 주민번호/전화번호 도용).
#
# **(2) 2단계: 사업자 책임 확인**
# - 게임사가 **실명 인증 절차를 이행했는지** 확인.
#   - 2005년 6월 이후 실명 인증이 의무화된 경우, 비실명 계정을 방치한 사업자에게 부분 책임 발생 가능.
# - **보안 조치 미비** (예: 신용카드 4중 보안장치 미적용) 시 사업자 책임 증가.
#
# **(3) 3단계: 환불 요청 전략**
# - **미성년자 본인 명의 결제**: 민법 제5조에 따라 계약 취소 및 전액 환불 요청.
# - **타인 명의 도용 또는 사술**:
#   - 사업자가 실명 확인을 소홀히 한 경우, **부분 환불** (예: 35~65%)을 조정위원회에 신청.
#   - 미성년자가 성인인 것처럼 고의로 속인 경우, 환불 불가능하나, 사업자의 보안 미비로 부분 책임 주장 가능.
#
# **(4) 4단계: 분쟁조정 신청**
# - 전자거래분쟁조정위원회에 조정 신청 시, **결제 내역, 계정 정보, 사업자 과실 증거** 제출.
# - 유사 사례(2008_부당결제대금 반환 청구)를 참고해 **손해 분담 비율**을 주장.
#
# #### 5. **한계 사항**
# - 제시된 사례집에는 **신용카드 부정사용 시 사업자의 보안 조치 기준**이 명시되지 않아, 해당 부분은 추가 검토가 필요합니다.
# - **게임머니 현금화(카드깡)**와 같은 불법 행위는 환불 대상에서 제외될 수 있음(2008_신용카드 부정사용 사례 참조).
#
# ### 결론
# 미성년자의 게임 아이템 구매 환불 가능성은 **계약 취소 요건 충족 여부**와 **사업자의 실명 확인 의무 이행 여부**에 따라 달라집니다. 부모 동의 없이 미성년자 본인 명의로 결제한 경우 전액 환불이 가능하나, 타인 명의를 도용하거나 사술을 사용한 경우 부분 환불 또는 책임이 제한될 수 있습니다. 분쟁조정 시 유사 사례를 참고해 적극적으로 권리를 주장하시기 바랍니다.
#
#  참조 문서:
#    1. 페이지 50: 1. 게임 45■ 1-나 전자거래분쟁조정위원회 조정결정례 2008_부당결제대금 반환 청구 【사건개요 】 신청인의 자녀는 2004. 4. 22. ...
#    2. 페이지 43: 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 38■ 1-나 전자거래분쟁조정위원회 조정결정례 2006_미성년자 단독으로 한 결제 취...
#    3. 페이지 51: 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 46라 구입대금의 지급 책임도 신청인의 미성년자 자녀에게 있다고 할 것이며 , 또한 ...
#
# ----------------------------------------
#
# 【테스트 5/5】
#  질문: 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# ### 전문 법률 조언: 온라인 교육 서비스 계약 해지 및 환급 요구
#
# #### 1. **계약 해지 가능성**
# 제시된 사례(2007~2010년 한국소비자원 조정결정례)에 따르면, **온라인 교육 서비스 계약은 「방문판매 등에 관한 법률」 제29조**에 따라 **소비자가 언제든지 해지할 수 있는 "계속적 거래"**에 해당합니다.
# - **사례 2010_온라인교육 서비스 계약 해지**에서 소비자는 대학 합격으로 인해 계약 해지 의사를 표시했고, 이는 정당한 사유로 인정되었습니다.
# - **사례 2007_인터넷교육서비스 중도해지 요구**에서도 서비스 불만 사유로 해지 요청이 가능했습니다.
#
# 따라서 **광고와 실제 서비스 내용이 다른 경우**, 계약 해지 사유가 될 수 있으며, 이는 「소비자기본법」 제16조(소비자분쟁해결기준) 및 「방문판매법」 제30조(위약금 제한)에 따라 보호받습니다.
#
# ---
#
# #### 2. **환급금 산정 기준**
# 환급금은 다음 원칙에 따라 계산됩니다:
# - **실제 이용 기간**에 따른 비용 공제 후 잔액 환급
#   - **사례 2008_온라인 통신교육서비스 이용료 환급**에서는 "할인 전 계약금액"을 기준으로 공제 후 환급이 결정되었습니다.
#   - **사례 2007_온라인통신교육서비스 대금 환급 요구2**에서는 사업자가 교재비·위약금 등을 과도하게 공제한 것이 부당하다고 판단되었습니다.
# - **위약금 제한**: 「방문판매법」 제30조에 따라 **해지로 인한 손실을 현저히 초과하는 위약금은 무효**입니다.
#   - 예: 1년 계약 중 1개월 미만 이용 시 2/3 공제 주장은 기각됨(사례 2010_온라인교육 서비스).
# - **소비자분쟁해결기준(공정위 고시)** 적용:
#   - 일반적으로 **이용일수 × 월 이용료 + 총 이용금액의 10% 이내 위약금**을 공제한 잔액 환급이 원칙입니다(사례 2007_인터넷교육서비스 중도해지).
#
# ---
#
# #### 3. **실무적 해결 단계**
# **(1) 계약 해지 통보**
# - 서면(이메일, 내용증명)으로 해지 의사를 명확히 전달하고, **광고와 다른 서비스 내용을 구체적으로 기재**합니다.
#   - 예: "광고에 명시된 강의 수/강사진/서비스 품질이 실제와 달라 계약 목적을 달성할 수 없음"을 명시.
#
# **(2) 환급금 산정 요청**
# - 계약서에 명시된 **월 이용료**를 기준으로 이용 기간 공제 후 잔액을 계산합니다.
# - 사업자가 추가 비용(교재비, 가입비 등)을 공제하려는 경우, **계약서 명시 여부**를 확인합니다.
#   - 계약서에 명시되지 않은 비용은 공제 대상이 아닙니다(사례 2007_온라인통신교육서비스 대금 환급 요구2).
#
# **(3) 분쟁 조정 신청**
# - 사업자가 환급 요구에 응하지 않을 경우, **한국소비자원에 분쟁 조정**을 신청합니다.
#   - 조정 사례(2007~2010년)에 따르면, 과도한 위약금 공제는 대부분 소비자 승소 사례가 있습니다.
#
# ---
#
# #### 4. **주의사항**
# - **사례집에 없는 내용**:
#   - "광고와 서비스 불일치"로 인한 해지 시 **손해배상 청구** 가능성은 제시된 사례에서 확인되지 않았습니다.
#   - 단, 「전자상거래법」 제18조(청약철회)에 따라 **계약 체결일 또는 서비스 제공 시작일로부터 7일 이내**에는 무조건 해지권이 인정될 수 있으나, 이는 사례집에 언급되지 않았습니다.
#
# ---
#
# ### 결론
# **광고와 다른 서비스 제공**은 계약 해지 사유가 되며, 환급금은 **이용 기간 공제 + 10% 이내 위약금**을 적용해 산정해야 합니다. 사업자가 부당한 비용을 공제하려 할 경우, 한국소비자원에 조정을 신청하는 것이 효과적입니다.
#
# > ✅ **추천 조치**:
# > 1. 해지 통보 및 환급 요청 서면 발송
# > 2. 계약서 상 이용료 기준 환급금 계산
# > 3. 사업자 거부 시 한국소비자원 조정 신청 (www.kca.go.kr)
#
#  참조 문서:
#    1. 페이지 3: 2007_ 온라인통신교육서비스 대금 환급 요구2················································· 5 5 ...
#    2. 페이지 74: 2. 이러닝 69■ 2-가 한국소비자원 조정결정례 2010_온라인교육 서비스 계약 해지에 따른 이용요금 환급 요구 【사건개요 】 신청인은 200...
#    3. 페이지 64: 2. 이러닝 59■ 2-가 한국소비자원 조정결정례 2008_온라인 통신교육서비스 이용료 환급 요구 【사건개요 】 신청인은 2007. 8. 8. ...
#
# ----------------------------------------
